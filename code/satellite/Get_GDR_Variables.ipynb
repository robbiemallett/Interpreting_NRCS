# %%
from netCDF4 import Dataset

# %%
d = Dataset('/home/robbie/Dropbox/kuka_bare/data/satellite/SRL_GPN_2PfP003_0003_20130523_071926_20130523_080943.CNES.nc')

for i in list(d.variables):
    print()
    print()
    print(i)
    print(d[i])
# Out:
# time
# <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     long_name: time (sec. since 2000-01-01)
#     standard_name: time
#     calendar: gregorian
#     units: seconds since 2000-01-01 00:00:00.0
#     comment: [tai_utc_difference] is the difference between TAI and UTC reference time (seconds) for the first measurement of the data set. [leap_second] is the UTC time at which a leap second occurs in the data set, if any. After this UTC time, the [tai_utc_difference] is increased by 1 second
#     tai_utc_difference: -35.0
#     leap_second: 0000-00-00 00:00:00
# unlimited dimensions:
# current shape = (2850,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
#
# meas_ind
# <class 'netCDF4._netCDF4.Variable'>
# int8 meas_ind(meas_ind)
#     long_name: elementary measurement index
#     units: count
#     comment: Set to be compliant with the CF-1.1 convention
# unlimited dimensions:
# current shape = (40,)
# filling on, default _FillValue of -127 ignored
#
# ...

# %%
d = Dataset('/home/robbie/Dropbox/kuka_bare/data/satellite/CS_LTA__SIR_SAR_2__20150601T005718_20150601T010118_D001.nc')

for i in list(d.variables):
    print()
    print()
    print(i)
    print(d[i])

# %%
x = np.arange(0,10)

y=np.repeat(x[:,np.newaxis],40,axis=1)

y.shape
# Out:
# (10, 40)
