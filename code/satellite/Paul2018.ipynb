# %%
import scipy
from netCDF4 import Dataset
import numpy as np
from scipy.spatial import KDTree
from ll_xy import lonlat_to_xy
import itertools
import matplotlib.pyplot as plt
import datetime
import calendar
import pandas as pd
import tqdm
import os
import matplotlib.pyplot as plt
import numpy as np
import cartopy
import cartopy.crs as ccrs
import pickle

# %%
months = ['Oct','Nov','Dec','Jan','Feb','Mar','Apr']
values = [28.0,25.8,24.1,23.8,23.2,23.3,23.4]


plt.plot(values,marker='o')
plt.ylabel('CryoSat-2 SAR-Mode\nLead Thresholds',fontsize='x-large')
plt.xticks(np.arange(len(months)),months,fontsize='x-large')
plt.ylim(5,40)
plt.show()
